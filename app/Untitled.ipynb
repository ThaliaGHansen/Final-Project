# %%
#Dependencies
import time
import warnings

import numpy as np
import matplotlib.pyplot as plt

from sklearn import cluster, datasets, mixture
from sklearn.neighbors import kneighbors_graph
from sklearn.preprocessing import StandardScaler
from itertools import cycle, islice

np.random.seed(0)

# %%
Skitdata_df = pd.read_csv("skittles.csv")
Skitdata_df.head()
# Out:
#    bag_number  purple  green  red  yellow  orange  total_perf  d_purple  \
# 0           1       3     25    6      14       6          54         0
# 1           2      12     11   10      14       9          56         0
# 2           3       8     13    6      17      10          54         0
# 3           4      13      9   12       9      10          53         1
# 4           5      13      7    8      13      11          52         0
#
#    d_green  d_red  d_yellow  d_orange  total_def  bag_total  Unnamed: 14  \
# 0        0      2         1         1          4         58           55
# 1        1      2         1         4          8         64           58
# 2        5      0         1         1          7         61           57
# 3        0      2         1         1          5         58           57
# 4        0      1         1         3          5         57           57
#
#    Unnamed: 15 per_of_probability_defects_per_bag  \
# ...

# %%
# # Probability of Defects vs. Normal data calculations

# %%
Skitdata_df.plot(kind='bar')
plt.ylabel('Frequency')
plt.xlabel('Skittles bag')
plt.title('Title')



plt.show()

# %%
Skitdata_df.hist(bins=10)
plt.xlim([0,100])
plt.ylim([50,500])
plt.title("Data")
plt.xlabel("Skittles bag")
plt.ylabel("Frequency")
plt.show()



# X = Skitdata_df[:, 1:]  # select columns 1 through end
# y = Skitdata_df[:, 0]   # select column 0, the stock price

# %%
# import the seaborn module
import seaborn as sns
# set the background colour of the plot to white
sns.set(style="whitegrid", color_codes=True)
# setting the plot size for all plots
sns.set(rc={'figure.figsize':(10,9)})
# create a countplot
sns.countplot('total_def',data=Skitdata_df,hue = 'per_of_probability_defects_per_bag')
# Remove the top and down margin
sns.despine(offset=20, trim=True)
# display the plotplt.show()

# %%
import numpy as np; np.random.seed(0)
import seaborn as sns; sns.set()
Skitdata_df = np.random.rand(10, 12)
ax = sns.heatmap(Skitdata_df)

# %%
ax = sns.heatmap(Skitdata_df, vmin=0, vmax=1)

# %%
>>> Skitdata_df = np.random.randn(10, 12)
>>> ax = sns.heatmap(Skitdata_df, center=0)

# %%
>>> Skitdata_df = sns.load_dataset("flights")
>>> Skitdata_df = flights.pivot("month", "year", "passengers")
>>> ax = sns.heatmap(flights)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-79-841336e66769> in <module>
# ----> 1 Skitdata_df = sns.load_dataset("")
#       2 Skitdata_df = Skitdata_df.pivot("month", "year", "passengers")
#       3 ax = sns.heatmap(flights)
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/utils.py in load_dataset(name, cache, data_home, **kws)
#     426                                   os.path.basename(full_path))
#     427         if not os.path.exists(cache_path):
# --> 428             urlretrieve(full_path, cache_path)
#     429         full_path = cache_path
#     430
#
# ~/anaconda3/lib/python3.7/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     245     url_type, path = splittype(url)
#     246
# --> 247     with contextlib.closing(urlopen(url, data)) as fp:
#     248         headers = fp.info()
#     249
#
# ...

# %%
>>> ax = sns.heatmap(flights, annot=True, fmt="d")
